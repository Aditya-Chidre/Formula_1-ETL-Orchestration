# %%
# Unity Catalog Object Names
catalog_name = 'formula1'
bronze_schema = 'bronze'
silver_schema = 'silver'
gold_schema = 'gold'

# %%
landing_folder_path = "/Volumes/formula1/default/raw_data/full_load/landing"
