# %%
# Unity Catalog Object Names
catalog_name = 'formula1_incr'
bronze_schema = 'bronze'
silver_schema = 'silver'
gold_schema = 'gold'
control_schema = 'control'

# %%
landing_folder_path = "/Volumes/formula1_incr/default/incr_load"
